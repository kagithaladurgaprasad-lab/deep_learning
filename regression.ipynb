# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import KBinsDiscretizer
from sklearn.datasets import load_iris
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score ,classification_report

# %%
df=pd.read_csv('AQI.csv')

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['PM2.5']=df['PM2.5'].fillna(df['PM2.5'].median())

# %%
df['PM10']=df['PM10'].fillna(df['PM10'].median())

# %%
df['NO']=df['NO'].fillna(df['NO'].median())

# %%
df['NO2']=df['NO2'].fillna(df['NO2'].median())

# %%
df['NOx']=df['NOx'].fillna(df['NOx'].median())

# %%
df['NH3']=df['NH3'].fillna(df['NH3'].median())

# %%
df['CO']=df['CO'].fillna(df['CO'].median())

# %%
df['SO2']=df['SO2'].fillna(df['SO2'].median())

# %%
df['O3']=df['O3'].fillna(df['O3'].median())

# %%
df['Benzene']=df['Benzene'].fillna(df['Benzene'].median())

# %%
df['Toluene']=df['Toluene'].fillna(df['Toluene'].median())

# %%
df['Xylene']=df['Xylene'].fillna(df['Xylene'].median())

# %%
df.describe(include='all')
# Out:
#              City        Date         PM2.5          PM10            NO  \
# count       29531       29531  29531.000000  29531.000000  29531.000000
# unique         26        2009           NaN           NaN           NaN
# top     Ahmedabad  2020-06-26           NaN           NaN           NaN
# freq         2009          26           NaN           NaN           NaN
# mean          NaN         NaN     64.510857    109.659366     16.642601
# std           NaN         NaN     59.807551     72.324020     21.506064
# min           NaN         NaN      0.040000      0.010000      0.020000
# 25%           NaN         NaN     32.150000     79.315000      6.210000
# 50%           NaN         NaN     48.570000     95.680000      9.890000
# 75%           NaN         NaN     72.450000    111.880000     17.570000
# max           NaN         NaN    949.990000   1000.000000    390.680000
#
#                  NO2           NOx           NH3            CO           SO2  \
# count   29531.000000  29531.000000  29531.000000  29531.000000  29531.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean       27.726576     31.063568     20.813789      2.153872     13.830897
# std        23.050531     29.477748     21.028862      6.724660     17.005647
# min         0.010000      0.000000      0.010000      0.000000      0.010000
# 25%        12.980000     14.670000     12.040000      0.540000      6.090000
# 50%        21.690000     23.520000     15.850000      0.890000      9.160000
# 75%        34.665000     36.015000     21.755000      1.380000     13.810000
# max       362.210000    467.630000    352.890000    175.810000    193.860000
#
#                   O3       Benzene       Toluene        Xylene           AQI  \
# count   29531.000000  29531.000000  29531.000000  29531.000000  24850.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean       33.994121      2.859874      7.140485      1.788420    166.463581
# std        20.202304     14.252822     17.224737      4.062039    140.696585
# min         0.010000      0.000000      0.000000      0.000000     13.000000
# 25%        20.740000      0.240000      1.280000      0.980000     81.000000
# 50%        30.840000      1.070000      2.970000      0.980000    118.000000
# 75%        42.730000      2.420000      6.020000      0.980000    208.000000
# max       257.730000    455.030000    454.850000    170.370000   2049.000000
#
#        AQI_Bucket
# count       24850
# unique          6
# top      Moderate
# freq         8829
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN

# %%
df.isnull().sum()
# Out:
# City             0
# Date             0
# PM2.5            0
# PM10             0
# NO               0
# NO2              0
# NOx              0
# NH3              0
# CO               0
# SO2              0
# O3               0
# Benzene          0
# Toluene          0
# Xylene           0
# AQI           4681
# AQI_Bucket    4681
# dtype: int64

# %%
df['AQI']=df['AQI'].fillna(df['AQI'].median())

# %%
df['AQI_Bucket']=df['AQI_Bucket'].fillna(df['AQI_Bucket'].mode()[0])

# %%
df.isnull().sum()
# Out:
# City          0
# Date          0
# PM2.5         0
# PM10          0
# NO            0
# NO2           0
# NOx           0
# NH3           0
# CO            0
# SO2           0
# O3            0
# Benzene       0
# Toluene       0
# Xylene        0
# AQI           0
# AQI_Bucket    0
# dtype: int64

# %%
x=df.drop(['AQI'],axis=1)

# %%
y=df['AQI']

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import math

num_cols = x.select_dtypes(include='number').columns

n_cols = 3   # number of columns in subplot
n_rows = math.ceil(len(num_cols) / n_cols)

plt.figure(figsize=(15, 5 * n_rows))

for i, col in enumerate(num_cols):
    plt.subplot(n_rows, n_cols, i + 1)

    sns.boxplot(y=x[col])

    plt.title(col)

plt.tight_layout()
plt.show()

# %%
num_cols = x.select_dtypes(include=['int64', 'float64']).columns

def cap_outliers(x, cols):
    x = x.copy()
    
    for col in cols:
        Q1 = x[col].quantile(0.25)
        Q3 = x[col].quantile(0.75)
        IQR = Q3 - Q1
        
        lower = Q1 - 1.5 * IQR
        upper = Q3 + 1.5 * IQR
        
        x[col] = x[col].clip(lower, upper)
    
    return x

x = cap_outliers(x, num_cols)

# %%
num_cols = x.select_dtypes(include='number').columns

n_cols = 3   # number of columns in subplot
n_rows = math.ceil(len(num_cols) / n_cols)

plt.figure(figsize=(15, 5 * n_rows))

for i, col in enumerate(num_cols):
    plt.subplot(n_rows, n_cols, i + 1)

    sns.boxplot(y=x[col])

    plt.title(col)

plt.tight_layout()
plt.show()

# %%
from sklearn.preprocessing import OneHotEncoder,StandardScaler
from sklearn.compose import ColumnTransformer

# %%
cat_cols=x.select_dtypes(include='object').columns
cat_cols
# Out:
# Index(['City', 'Date', 'AQI_Bucket'], dtype='object')

# %%
num_cols=x.select_dtypes(include='number').columns
num_cols
# Out:
# Index(['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3',
#        'Benzene', 'Toluene', 'Xylene'],
#       dtype='object')

# %%
# train test split
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42
)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OrdinalEncoder, MinMaxScaler

ct = ColumnTransformer(
    transformers=[
        ("oe", OrdinalEncoder(), cat_cols),
        ("mm", MinMaxScaler(), num_cols)
    ],
    remainder='passthrough'
)

# %%
x_train_transform=ct.fit_transform(x_train)

# %%
x_train_transform=pd.DataFrame(x_train_transform)

# %%
x_test_transform=ct.fit_transform(x_test)
x_test_transform=pd.DataFrame(x_test_transform)

# %%
from tensorflow.keras.models import Sequential

# %%
from keras.layers import Dense,BatchNormalization

# %%
model=Sequential()

#add input layer 
model.add(Dense(15,activation='relu',input_shape=(15,)))
model.add(BatchNormalization())

#hidden layer 
model.add(Dense(25,activation="relu"))
model.add(BatchNormalization())
#add output layer 
model.add(Dense(1))
# Out:
# C:\Users\admin\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
import tensorflow as tf

# %%
#compile the model
model.compile(optimizer='adam',loss='mse',metrics=[tf.keras.metrics.R2Score()])
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
price=model.fit(x_train_transform,y_train,epochs=30,batch_size=8,verbose=1,validation_split=0.2)
# Out:
# Epoch 1/30
# 2363/2363 ━━━━━━━━━━━━━━━━━━━━ 16s 5ms/step - loss: 24449.3184 - r2_score: -0.3957 - val_loss: 23223.0352 - val_r2_score: -0.3871
# Epoch 2/30
# 2363/2363 ━━━━━━━━━━━━━━━━━━━━ 19s 4ms/step - loss: 8957.0205 - r2_score: 0.4887 - val_loss: 8785.1182 - val_r2_score: 0.4753
# Epoch 3/30
# 2363/2363 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - loss: 8613.3350 - r2_score: 0.5083 - val_loss: 9329.3164 - val_r2_score: 0.4428
# Epoch 4/30
# 2363/2363 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - loss: 8347.6592 - r2_score: 0.5235 - val_loss: 8976.1455 - val_r2_score: 0.4639
# Epoch 5/30
# 2363/2363 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 8232.7822 - r2_score: 0.5300 - val_loss: 25150.0605 - val_r2_score: -0.5022
# Epoch 6/30
# 2363/2363 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - loss: 8488.9072 - r2_score: 0.5154 - val_loss: 11749.8730 - val_r2_score: 0.2982
# Epoch 7/30
# 2363/2363 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step - loss: 8305.0674 - r2_score: 0.5259 - val_loss: 30714.2461 - val_r2_score: -0.8345
# Epoch 8/30
# 2363/2363 ━━━━━━━━━━━━━━━━━━━━ 22s 5ms/step - loss: 8464.9932 - r2_score: 0.5168 - val_loss: 10838.1436 - val_r2_score: 0.3527
# Epoch 9/30
# 2363/2363 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step - loss: 8569.1504 - r2_score: 0.5108 - val_loss: 15945.1475 - val_r2_score: 0.0476
# Epoch 10/30
# 2363/2363 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - loss: 8401.3418 - r2_score: 0.5204 - val_loss: 23990.9258 - val_r2_score: -0.4329
# Epoch 11/30
# 2363/2363 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - loss: 8406.2646 - r2_score: 0.5201 - val_loss: 54638.7266 - val_r2_score: -2.2634
# Epoch 12/30
# 2363/2363 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - loss: 8355.1523 - r2_score: 0.5230 - val_loss: 15826.6416 - val_r2_score: 0.0547
# Epoch 13/30
# 2363/2363 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - loss: 8167.6304 - r2_score: 0.5337 - val_loss: 21301.2344 - val_r2_score: -0.2723
# Epoch 14/30
# 2363/2363 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - loss: 8134.7661 - r2_score: 0.5356 - val_loss: 37181.7227 - val_r2_score: -1.2208
# Epoch 15/30
# 2363/2363 ━━━━━━━━━━━━━━━━━━━━ 19s 4ms/step - loss: 8221.0566 - r2_score: 0.5307 - val_loss: 30197.7188 - val_r2_score: -0.8036
# Epoch 16/30
# 2363/2363 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 8381.2646 - r2_score: 0.5215 - val_loss: 19048.1953 - val_r2_score: -0.1377
# Epoch 17/30
# 2363/2363 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - loss: 8170.2998 - r2_score: 0.5336 - val_loss: 19264.4004 - val_r2_score: -0.1506
# Epoch 18/30
# 2363/2363 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - loss: 8261.4971 - r2_score: 0.5284 - val_loss: 27429.7520 - val_r2_score: -0.6383
# Epoch 19/30
# 2363/2363 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step - loss: 8379.5898 - r2_score: 0.5216 - val_loss: 23156.4727 - val_r2_score: -0.3831
# Epoch 20/30
# 2363/2363 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 7846.4849 - r2_score: 0.5521 - val_loss: 11562.2510 - val_r2_score: 0.3094
# Epoch 21/30
# 2363/2363 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 7788.8989 - r2_score: 0.5554 - val_loss: 43523.1797 - val_r2_score: -1.5995
# Epoch 22/30
# 2363/2363 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 7688.0835 - r2_score: 0.5611 - val_loss: 9212.4170 - val_r2_score: 0.4498
# Epoch 23/30
# 2363/2363 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - loss: 7793.2324 - r2_score: 0.5551 - val_loss: 7786.4482 - val_r2_score: 0.5349
# Epoch 24/30
# 2363/2363 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - loss: 7671.3325 - r2_score: 0.5621 - val_loss: 4667.2031 - val_r2_score: 0.7212
# Epoch 25/30
# 2363/2363 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - loss: 7646.9028 - r2_score: 0.5635 - val_loss: 12449.0400 - val_r2_score: 0.2564
# Epoch 26/30
# 2363/2363 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step - loss: 7603.7886 - r2_score: 0.5659 - val_loss: 5326.3545 - val_r2_score: 0.6819
# Epoch 27/30
# 2363/2363 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - loss: 7952.6157 - r2_score: 0.5460 - val_loss: 14497.6172 - val_r2_score: 0.1341
# Epoch 28/30
# 2363/2363 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - loss: 7649.3521 - r2_score: 0.5633 - val_loss: 4921.2485 - val_r2_score: 0.7061
# Epoch 29/30
# 2363/2363 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - loss: 7470.8960 - r2_score: 0.5735 - val_loss: 8942.7500 - val_r2_score: 0.4659
# Epoch 30/30
# 2363/2363 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - loss: 7457.6304 - r2_score: 0.5743 - val_loss: 43572.8359 - val_r2_score: -1.6025

# %%
r2=model.evaluate(x_test_transform,y_test)
# Out:
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 37898.1211 - r2_score: -1.4618

# %%
import matplotlib.pyplot as plt

#Extract metrics from the history object
acc = price.history['r2_score']
val_acc = price.history['val_r2_score']
loss = price.history['loss']
val_loss = price.history['val_loss']
epochs = range(1, len(acc) + 1)

#Plot Accuracy
plt.figure(figsize=(10, 4))
plt.title("Results with adam")
plt.subplot(1, 2, 1)
plt.plot(epochs, acc, 'bo-', label='Training Accuracy')
plt.plot(epochs, val_acc, 'ro-', label='Validation Accuracy')
plt.title('Model Accuracy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

#Plot Loss
plt.subplot(1, 2, 2)
plt.plot(epochs, loss, 'bo-', label='Training Loss')
plt.plot(epochs, val_loss, 'ro-', label='Validation Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
